# %% [markdown]
# # 1. Apple's Balance Sheet

# %% [markdown]
# ### Preparation
# We have to search Edgar for Apple Inc. and open its 10-K, and then switch to an HTML rendering of the content.
# Then locate its balance sheet, which turns out to be on page 33.
#
# We'll use a snippet from that table as our search pattern

# %% [markdown]
# ### Data Pulling

# %%
import pandas as pd
import requests

# %%
URL = 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926.htm'
# I had to experiment with a few different patterns finding this phrase got exactly one result
PATTERN = 'additional paid-in capital,'

# %%
html = requests.get(URL).content
result = pd.read_html(html, match=PATTERN)

# %%
# did we get a uniquely matching table? yes
len(result)
# Out:
# 1

# %%
df = result[0]

# %%
df.head()
# Out:
#                           0                          1   \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                    ASSETS:                    ASSETS:
# 3            Current assets:            Current assets:
# 4  Cash and cash equivalents  Cash and cash equivalents
#
#                           2                  3                  4   \
# 0                        NaN                NaN                NaN
# 1                        NaN  September 26,2020  September 26,2020
# 2                    ASSETS:            ASSETS:            ASSETS:
# 3            Current assets:                NaN                NaN
# 4  Cash and cash equivalents                  $              38016
#
#                   5        6        7        8                  9   \
# 0                NaN      NaN      NaN      NaN                NaN
# 1  September 26,2020      NaN      NaN      NaN  September 28,2019
# 2            ASSETS:  ASSETS:  ASSETS:  ASSETS:            ASSETS:
# 3                NaN      NaN      NaN      NaN                NaN
# 4                NaN      NaN      NaN      NaN                  $
#
#                   10                 11
# 0                NaN                NaN
# 1  September 28,2019  September 28,2019
# 2            ASSETS:            ASSETS:
# 3                NaN                NaN
# 4              48844                NaN

# %% [markdown]
# ### Post-processing

# %%
# Drop columns with no info or duplicate data
df = df.drop([1, 2, 3, 5, 6, 7, 8, 9, 11], axis=1)
df.head()
# Out:
#                           0                  4                  10
# 0                        NaN                NaN                NaN
# 1                        NaN  September 26,2020  September 28,2019
# 2                    ASSETS:            ASSETS:            ASSETS:
# 3            Current assets:                NaN                NaN
# 4  Cash and cash equivalents              38016              48844

# %%
# Rename columns appropriately
df.columns = ['label', 'fy_2020', 'fy_2019']
df
# Out:
#                                                 label  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                             ASSETS:
# 3                                     Current assets:
# 4                           Cash and cash equivalents
# 5                               Marketable securities
# 6                            Accounts receivable, net
# 7                                         Inventories
# 8                        Vendor non-trade receivables
# 9                                Other current assets
# 10                               Total current assets
# 11                                                NaN
# 12                                Non-current assets:
# 13                              Marketable securities
# 14                 Property, plant and equipment, net
# 15                           Other non-current assets
# 16                           Total non-current assets
# 17                                       Total assets
# 18                                                NaN
# 19              LIABILITIES AND SHAREHOLDERS’ EQUITY:
# 20                               Current liabilities:
# 21                                   Accounts payable
# 22                          Other current liabilities
# 23                                   Deferred revenue
# 24                                   Commercial paper
# 25                                          Term debt
# 26                          Total current liabilities
# 27                                                NaN
# 28                           Non-current liabilities:
# 29                                          Term debt
# 30                      Other non-current liabilities
# 31                      Total non-current liabilities
# 32                                  Total liabilities
# 33                                                NaN
# 34                      Commitments and contingencies
# 35                                                NaN
# 36                              Shareholders’ equity:
# 37  Common stock and additional paid-in capital, $...
# 38                                  Retained earnings
# 39      Accumulated other comprehensive income/(loss)
# 40                         Total shareholders’ equity
# 41         Total liabilities and shareholders’ equity
#
#                                   fy_2020  \
# 0                                     NaN
# 1                       September 26,2020
# 2                                 ASSETS:
# 3                                     NaN
# 4                                   38016
# 5                                   52927
# 6                                   16120
# 7                                    4061
# 8                                   21325
# 9                                   11264
# 10                                 143713
# 11                                    NaN
# 12                                    NaN
# 13                                 100887
# 14                                  36766
# 15                                  42522
# 16                                 180175
# 17                                 323888
# 18                                    NaN
# 19  LIABILITIES AND SHAREHOLDERS’ EQUITY:
# 20                                    NaN
# 21                                  42296
# 22                                  42684
# 23                                   6643
# 24                                   4996
# 25                                   8773
# 26                                 105392
# 27                                    NaN
# 28                                    NaN
# 29                                  98667
# 30                                  54490
# 31                                 153157
# 32                                 258549
# 33                                    NaN
# 34                                    NaN
# 35                                    NaN
# 36                                    NaN
# 37                                  50779
# 38                                  14966
# 39                                  (406)
# 40                                  65339
# 41                                 323888
#
#                                   fy_2019
# 0                                     NaN
# 1                       September 28,2019
# 2                                 ASSETS:
# 3                                     NaN
# 4                                   48844
# 5                                   51713
# 6                                   22926
# 7                                    4106
# 8                                   22878
# 9                                   12352
# 10                                 162819
# 11                                    NaN
# 12                                    NaN
# 13                                 105341
# 14                                  37378
# 15                                  32978
# 16                                 175697
# 17                                 338516
# 18                                    NaN
# 19  LIABILITIES AND SHAREHOLDERS’ EQUITY:
# 20                                    NaN
# 21                                  46236
# 22                                  37720
# 23                                   5522
# 24                                   5980
# 25                                  10260
# 26                                 105718
# 27                                    NaN
# 28                                    NaN
# 29                                  91807
# 30                                  50503
# 31                                 142310
# 32                                 248028
# 33                                    NaN
# 34                                    NaN
# 35                                    NaN
# 36                                    NaN
# 37                                  45174
# 38                                  45898
# 39                                  (584)
# 40                                  90488
# 41                                 338516

# %%
# The information in the first two rows (date of financial statement) is encoded in the
# column names, so they can be dropped.
df = df.drop([0, 1], axis=0)
df.head()
# Out:
#                        label  fy_2020  fy_2019
# 2                    ASSETS:  ASSETS:  ASSETS:
# 3            Current assets:      NaN      NaN
# 4  Cash and cash equivalents    38016    48844
# 5      Marketable securities    52927    51713
# 6   Accounts receivable, net    16120    22926

# %%
# Move the labels into our row index
df = df.set_index('label')
df
# Out:
#                                                                                   fy_2020  \
# label
# ASSETS:                                                                           ASSETS:
# Current assets:                                                                       NaN
# Cash and cash equivalents                                                           38016
# Marketable securities                                                               52927
# Accounts receivable, net                                                            16120
# Inventories                                                                          4061
# Vendor non-trade receivables                                                        21325
# Other current assets                                                                11264
# Total current assets                                                               143713
# NaN                                                                                   NaN
# Non-current assets:                                                                   NaN
# Marketable securities                                                              100887
# Property, plant and equipment, net                                                  36766
# Other non-current assets                                                            42522
# Total non-current assets                                                           180175
# Total assets                                                                       323888
# NaN                                                                                   NaN
# LIABILITIES AND SHAREHOLDERS’ EQUITY:               LIABILITIES AND SHAREHOLDERS’ EQUITY:
# Current liabilities:                                                                  NaN
# Accounts payable                                                                    42296
# Other current liabilities                                                           42684
# Deferred revenue                                                                     6643
# Commercial paper                                                                     4996
# Term debt                                                                            8773
# Total current liabilities                                                          105392
# NaN                                                                                   NaN
# Non-current liabilities:                                                              NaN
# Term debt                                                                           98667
# Other non-current liabilities                                                       54490
# Total non-current liabilities                                                      153157
# Total liabilities                                                                  258549
# NaN                                                                                   NaN
# Commitments and contingencies                                                         NaN
# NaN                                                                                   NaN
# Shareholders’ equity:                                                                 NaN
# Common stock and additional paid-in capital, $0...                                  50779
# Retained earnings                                                                   14966
# Accumulated other comprehensive income/(loss)                                       (406)
# Total shareholders’ equity                                                          65339
# Total liabilities and shareholders’ equity                                         323888
#
#                                                                                   fy_2019
# label
# ASSETS:                                                                           ASSETS:
# Current assets:                                                                       NaN
# Cash and cash equivalents                                                           48844
# Marketable securities                                                               51713
# Accounts receivable, net                                                            22926
# Inventories                                                                          4106
# Vendor non-trade receivables                                                        22878
# Other current assets                                                                12352
# Total current assets                                                               162819
# NaN                                                                                   NaN
# Non-current assets:                                                                   NaN
# Marketable securities                                                              105341
# Property, plant and equipment, net                                                  37378
# Other non-current assets                                                            32978
# Total non-current assets                                                           175697
# Total assets                                                                       338516
# NaN                                                                                   NaN
# LIABILITIES AND SHAREHOLDERS’ EQUITY:               LIABILITIES AND SHAREHOLDERS’ EQUITY:
# Current liabilities:                                                                  NaN
# Accounts payable                                                                    46236
# Other current liabilities                                                           37720
# Deferred revenue                                                                     5522
# Commercial paper                                                                     5980
# Term debt                                                                           10260
# Total current liabilities                                                          105718
# NaN                                                                                   NaN
# Non-current liabilities:                                                              NaN
# Term debt                                                                           91807
# Other non-current liabilities                                                       50503
# Total non-current liabilities                                                      142310
# Total liabilities                                                                  248028
# NaN                                                                                   NaN
# Commitments and contingencies                                                         NaN
# NaN                                                                                   NaN
# Shareholders’ equity:                                                                 NaN
# Common stock and additional paid-in capital, $0...                                  45174
# Retained earnings                                                                   45898
# Accumulated other comprehensive income/(loss)                                       (584)
# Total shareholders’ equity                                                          90488
# Total liabilities and shareholders’ equity                                         338516

# %% [markdown]
# ### Extraction

# %%
# Make a list of the fields we want to keep.
keep = ['Total assets', 'Total current assets', 'Total non-current assets',
        'Total liabilities', 'Total current liabilities', 'Total non-current liabilities',
        "Total shareholders’ equity"] # I pasted the special apostrophe directly from copying the balance sheet

# %%
# Pull out their values from the DataFrame for Fiscal Year 2020
metrics = df.loc[keep, ['fy_2020']]
metrics
# Out:
#                               fy_2020
# label
# Total assets                   323888
# Total current assets           143713
# Total non-current assets       180175
# Total liabilities              258549
# Total current liabilities      105392
# Total non-current liabilities  153157
# Total shareholders’ equity      65339

# %% [markdown]
# Check the assets, liabilities, and equity add up.

# %%
# Remember to convernt numbers to integers! If you forget, the plus sign will just concatenate the strings.
current_assets = int(metrics.loc['Total current assets', 'fy_2020'])
noncurrent_assets = int(metrics.loc['Total non-current assets', 'fy_2020'])
expected = current_assets + noncurrent_assets
actual = int(metrics.loc['Total assets', 'fy_2020'])
expected, actual
# Out:
# (323888, 323888)

# %%
current_liab = int(metrics.loc['Total current liabilities', 'fy_2020'])
noncurrent_liab = int(metrics.loc['Total non-current liabilities', 'fy_2020'])
expected = current_liab + noncurrent_liab
actual = int(metrics.loc['Total liabilities', 'fy_2020'])
expected, actual
# Out:
# (258549, 258549)

# %%
assets = int(metrics.loc['Total assets', 'fy_2020'])
liab = int(metrics.loc['Total liabilities', 'fy_2020'])
equity = int(metrics.loc['Total shareholders’ equity']) # Note the magic single quote again
assets - liab, equity
# Out:
# (65339, 65339)

# %% [markdown]
# Everything looks right! Someone let the SEC know.

# %% [markdown]
# # 3. Apple's Cash Flows

# %% [markdown]
# ### Data Pulling

# %% [markdown]
# We'll use the same URL (because this is on the same web page) but a different search pattern.

# %%
URL = 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926.htm'
PATTERN = 'cash equivalents and restricted cash,'

# %%
html = requests.get(URL).content
result = pd.read_html(html, match=PATTERN)

# %%
# did we get a uniquely matching table? yes
len(result)
# Out:
# 1

# %%
df = result[0]

# %%
df
# Out:
#                                                    0   \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Cash, cash equivalents and restricted cash, be...
# 4                               Operating activities:
# 5                                          Net income
# 6   Adjustments to reconcile net income to cash ge...
# 7                       Depreciation and amortization
# 8                    Share-based compensation expense
# 9                         Deferred income tax benefit
# 10                                              Other
# 11       Changes in operating assets and liabilities:
# 12                           Accounts receivable, net
# 13                                        Inventories
# 14                       Vendor non-trade receivables
# 15               Other current and non-current assets
# 16                                   Accounts payable
# 17                                   Deferred revenue
# 18          Other current and non-current liabilities
# 19             Cash generated by operating activities
# 20                              Investing activities:
# 21                 Purchases of marketable securities
# 22  Proceeds from maturities of marketable securities
# 23       Proceeds from sales of marketable securities
# 24  Payments for acquisition of property, plant an...
# 25  Payments made in connection with business acqu...
# 26             Purchases of non-marketable securities
# 27            Proceeds from non-marketable securities
# 28                                              Other
# 29   Cash generated by/(used in) investing activities
# 30                              Financing activities:
# 31             Proceeds from issuance of common stock
# 32  Payments for taxes related to net share settle...
# 33    Payments for dividends and dividend equivalents
# 34                        Repurchases of common stock
# 35           Proceeds from issuance of term debt, net
# 36                            Repayments of term debt
# 37                Repayments of commercial paper, net
# 38                                              Other
# 39                  Cash used in financing activities
# 40  Increase/(Decrease) in cash, cash equivalents ...
# 41  Cash, cash equivalents and restricted cash, en...
# 42                 Supplemental cash flow disclosure:
# 43                    Cash paid for income taxes, net
# 44                             Cash paid for interest
#
#                                                    1   \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Cash, cash equivalents and restricted cash, be...
# 4                               Operating activities:
# 5                                          Net income
# 6   Adjustments to reconcile net income to cash ge...
# 7                       Depreciation and amortization
# 8                    Share-based compensation expense
# 9                         Deferred income tax benefit
# 10                                              Other
# 11       Changes in operating assets and liabilities:
# 12                           Accounts receivable, net
# 13                                        Inventories
# 14                       Vendor non-trade receivables
# 15               Other current and non-current assets
# 16                                   Accounts payable
# 17                                   Deferred revenue
# 18          Other current and non-current liabilities
# 19             Cash generated by operating activities
# 20                              Investing activities:
# 21                 Purchases of marketable securities
# 22  Proceeds from maturities of marketable securities
# 23       Proceeds from sales of marketable securities
# 24  Payments for acquisition of property, plant an...
# 25  Payments made in connection with business acqu...
# 26             Purchases of non-marketable securities
# 27            Proceeds from non-marketable securities
# 28                                              Other
# 29   Cash generated by/(used in) investing activities
# 30                              Financing activities:
# 31             Proceeds from issuance of common stock
# 32  Payments for taxes related to net share settle...
# 33    Payments for dividends and dividend equivalents
# 34                        Repurchases of common stock
# 35           Proceeds from issuance of term debt, net
# 36                            Repayments of term debt
# 37                Repayments of commercial paper, net
# 38                                              Other
# 39                  Cash used in financing activities
# 40  Increase/(Decrease) in cash, cash equivalents ...
# 41  Cash, cash equivalents and restricted cash, en...
# 42                 Supplemental cash flow disclosure:
# 43                    Cash paid for income taxes, net
# 44                             Cash paid for interest
#
#                                                    2                  3   \
# 0                                                 NaN                NaN
# 1                                                 NaN        Years ended
# 2                                                 NaN  September 26,2020
# 3   Cash, cash equivalents and restricted cash, be...                  $
# 4                               Operating activities:                NaN
# 5                                          Net income              57411
# 6   Adjustments to reconcile net income to cash ge...                NaN
# 7                       Depreciation and amortization              11056
# 8                    Share-based compensation expense               6829
# 9                         Deferred income tax benefit              (215)
# 10                                              Other               (97)
# 11       Changes in operating assets and liabilities:                NaN
# 12                           Accounts receivable, net               6917
# 13                                        Inventories              (127)
# 14                       Vendor non-trade receivables               1553
# 15               Other current and non-current assets            (9,588)
# 16                                   Accounts payable            (4,062)
# 17                                   Deferred revenue               2081
# 18          Other current and non-current liabilities               8916
# 19             Cash generated by operating activities              80674
# 20                              Investing activities:                NaN
# 21                 Purchases of marketable securities          (114,938)
# 22  Proceeds from maturities of marketable securities              69918
# 23       Proceeds from sales of marketable securities              50473
# 24  Payments for acquisition of property, plant an...            (7,309)
# 25  Payments made in connection with business acqu...            (1,524)
# 26             Purchases of non-marketable securities              (210)
# 27            Proceeds from non-marketable securities                 92
# 28                                              Other              (791)
# 29   Cash generated by/(used in) investing activities            (4,289)
# 30                              Financing activities:                NaN
# 31             Proceeds from issuance of common stock                880
# 32  Payments for taxes related to net share settle...            (3,634)
# 33    Payments for dividends and dividend equivalents           (14,081)
# 34                        Repurchases of common stock           (72,358)
# 35           Proceeds from issuance of term debt, net              16091
# 36                            Repayments of term debt           (12,629)
# 37                Repayments of commercial paper, net              (963)
# 38                                              Other              (126)
# 39                  Cash used in financing activities           (86,820)
# 40  Increase/(Decrease) in cash, cash equivalents ...           (10,435)
# 41  Cash, cash equivalents and restricted cash, en...                  $
# 42                 Supplemental cash flow disclosure:                NaN
# 43                    Cash paid for income taxes, net                  $
# 44                             Cash paid for interest                  $
#
#                    4                  5            6            7   \
# 0                 NaN                NaN          NaN          NaN
# 1         Years ended        Years ended  Years ended  Years ended
# 2   September 26,2020  September 26,2020          NaN          NaN
# 3               50224                NaN          NaN          NaN
# 4                 NaN                NaN          NaN          NaN
# 5               57411                NaN          NaN          NaN
# 6                 NaN                NaN          NaN          NaN
# 7               11056                NaN          NaN          NaN
# 8                6829                NaN          NaN          NaN
# 9               (215)                NaN          NaN          NaN
# 10               (97)                NaN          NaN          NaN
# 11                NaN                NaN          NaN          NaN
# 12               6917                NaN          NaN          NaN
# 13              (127)                NaN          NaN          NaN
# 14               1553                NaN          NaN          NaN
# 15            (9,588)                NaN          NaN          NaN
# 16            (4,062)                NaN          NaN          NaN
# 17               2081                NaN          NaN          NaN
# 18               8916                NaN          NaN          NaN
# 19              80674                NaN          NaN          NaN
# 20                NaN                NaN          NaN          NaN
# 21          (114,938)                NaN          NaN          NaN
# 22              69918                NaN          NaN          NaN
# 23              50473                NaN          NaN          NaN
# 24            (7,309)                NaN          NaN          NaN
# 25            (1,524)                NaN          NaN          NaN
# 26              (210)                NaN          NaN          NaN
# 27                 92                NaN          NaN          NaN
# 28              (791)                NaN          NaN          NaN
# 29            (4,289)                NaN          NaN          NaN
# 30                NaN                NaN          NaN          NaN
# 31                880                NaN          NaN          NaN
# 32            (3,634)                NaN          NaN          NaN
# 33           (14,081)                NaN          NaN          NaN
# 34           (72,358)                NaN          NaN          NaN
# 35              16091                NaN          NaN          NaN
# 36           (12,629)                NaN          NaN          NaN
# 37              (963)                NaN          NaN          NaN
# 38              (126)                NaN          NaN          NaN
# 39           (86,820)                NaN          NaN          NaN
# 40           (10,435)                NaN          NaN          NaN
# 41              39789                NaN          NaN          NaN
# 42                NaN                NaN          NaN          NaN
# 43               9501                NaN          NaN          NaN
# 44               3002                NaN          NaN          NaN
#
#              8                  9                  10                 11  \
# 0           NaN                NaN                NaN                NaN
# 1   Years ended        Years ended        Years ended        Years ended
# 2           NaN  September 28,2019  September 28,2019  September 28,2019
# 3           NaN                  $              25913                NaN
# 4           NaN                NaN                NaN                NaN
# 5           NaN              55256              55256                NaN
# 6           NaN                NaN                NaN                NaN
# 7           NaN              12547              12547                NaN
# 8           NaN               6068               6068                NaN
# 9           NaN              (340)              (340)                NaN
# 10          NaN              (652)              (652)                NaN
# 11          NaN                NaN                NaN                NaN
# 12          NaN                245                245                NaN
# 13          NaN              (289)              (289)                NaN
# 14          NaN               2931               2931                NaN
# 15          NaN                873                873                NaN
# 16          NaN            (1,923)            (1,923)                NaN
# 17          NaN              (625)              (625)                NaN
# 18          NaN            (4,700)            (4,700)                NaN
# 19          NaN              69391              69391                NaN
# 20          NaN                NaN                NaN                NaN
# 21          NaN           (39,630)           (39,630)                NaN
# 22          NaN              40102              40102                NaN
# 23          NaN              56988              56988                NaN
# 24          NaN           (10,495)           (10,495)                NaN
# 25          NaN              (624)              (624)                NaN
# 26          NaN            (1,001)            (1,001)                NaN
# 27          NaN               1634               1634                NaN
# 28          NaN            (1,078)            (1,078)                NaN
# 29          NaN              45896              45896                NaN
# 30          NaN                NaN                NaN                NaN
# 31          NaN                781                781                NaN
# 32          NaN            (2,817)            (2,817)                NaN
# 33          NaN           (14,119)           (14,119)                NaN
# 34          NaN           (66,897)           (66,897)                NaN
# 35          NaN               6963               6963                NaN
# 36          NaN            (8,805)            (8,805)                NaN
# 37          NaN            (5,977)            (5,977)                NaN
# 38          NaN              (105)              (105)                NaN
# 39          NaN           (90,976)           (90,976)                NaN
# 40          NaN              24311              24311                NaN
# 41          NaN                  $              50224                NaN
# 42          NaN                NaN                NaN                NaN
# 43          NaN                  $              15263                NaN
# 44          NaN                  $               3423                NaN
#
#              12           13           14                 15  \
# 0           NaN          NaN          NaN                NaN
# 1   Years ended  Years ended  Years ended        Years ended
# 2           NaN          NaN          NaN  September 29,2018
# 3           NaN          NaN          NaN                  $
# 4           NaN          NaN          NaN                NaN
# 5           NaN          NaN          NaN              59531
# 6           NaN          NaN          NaN                NaN
# 7           NaN          NaN          NaN              10903
# 8           NaN          NaN          NaN               5340
# 9           NaN          NaN          NaN           (32,590)
# 10          NaN          NaN          NaN              (444)
# 11          NaN          NaN          NaN                NaN
# 12          NaN          NaN          NaN            (5,322)
# 13          NaN          NaN          NaN                828
# 14          NaN          NaN          NaN            (8,010)
# 15          NaN          NaN          NaN              (423)
# 16          NaN          NaN          NaN               9175
# 17          NaN          NaN          NaN                (3)
# 18          NaN          NaN          NaN              38449
# 19          NaN          NaN          NaN              77434
# 20          NaN          NaN          NaN                NaN
# 21          NaN          NaN          NaN           (71,356)
# 22          NaN          NaN          NaN              55881
# 23          NaN          NaN          NaN              47838
# 24          NaN          NaN          NaN           (13,313)
# 25          NaN          NaN          NaN              (721)
# 26          NaN          NaN          NaN            (1,871)
# 27          NaN          NaN          NaN                353
# 28          NaN          NaN          NaN              (745)
# 29          NaN          NaN          NaN              16066
# 30          NaN          NaN          NaN                NaN
# 31          NaN          NaN          NaN                669
# 32          NaN          NaN          NaN            (2,527)
# 33          NaN          NaN          NaN           (13,712)
# 34          NaN          NaN          NaN           (72,738)
# 35          NaN          NaN          NaN               6969
# 36          NaN          NaN          NaN            (6,500)
# 37          NaN          NaN          NaN               (37)
# 38          NaN          NaN          NaN                  —
# 39          NaN          NaN          NaN           (87,876)
# 40          NaN          NaN          NaN               5624
# 41          NaN          NaN          NaN                  $
# 42          NaN          NaN          NaN                NaN
# 43          NaN          NaN          NaN                  $
# 44          NaN          NaN          NaN                  $
#
#                    16                 17
# 0                 NaN                NaN
# 1         Years ended        Years ended
# 2   September 29,2018  September 29,2018
# 3               20289                NaN
# 4                 NaN                NaN
# 5               59531                NaN
# 6                 NaN                NaN
# 7               10903                NaN
# 8                5340                NaN
# 9            (32,590)                NaN
# 10              (444)                NaN
# 11                NaN                NaN
# 12            (5,322)                NaN
# 13                828                NaN
# 14            (8,010)                NaN
# 15              (423)                NaN
# 16               9175                NaN
# 17                (3)                NaN
# 18              38449                NaN
# 19              77434                NaN
# 20                NaN                NaN
# 21           (71,356)                NaN
# 22              55881                NaN
# 23              47838                NaN
# 24           (13,313)                NaN
# 25              (721)                NaN
# 26            (1,871)                NaN
# 27                353                NaN
# 28              (745)                NaN
# 29              16066                NaN
# 30                NaN                NaN
# 31                669                NaN
# 32            (2,527)                NaN
# 33           (13,712)                NaN
# 34           (72,738)                NaN
# 35               6969                NaN
# 36            (6,500)                NaN
# 37               (37)                NaN
# 38                  —                NaN
# 39           (87,876)                NaN
# 40               5624                NaN
# 41              25913                NaN
# 42                NaN                NaN
# 43              10417                NaN
# 44               3022                NaN

# %% [markdown]
# ### Post-processing

# %% [markdown]
# Lots of useless columns in this one -- everything except 0, 4, 10, and 16.
#
# Instead of dropping all the other columns, we can use selection syntax to just keep those four.

# %%
df = df[[0, 4, 10, 16]]
df.head(10)
# Out:
#                                                   0                  4   \
# 0                                                NaN                NaN
# 1                                                NaN        Years ended
# 2                                                NaN  September 26,2020
# 3  Cash, cash equivalents and restricted cash, be...              50224
# 4                              Operating activities:                NaN
# 5                                         Net income              57411
# 6  Adjustments to reconcile net income to cash ge...                NaN
# 7                      Depreciation and amortization              11056
# 8                   Share-based compensation expense               6829
# 9                        Deferred income tax benefit              (215)
#
#                   10                 16
# 0                NaN                NaN
# 1        Years ended        Years ended
# 2  September 28,2019  September 29,2018
# 3              25913              20289
# 4                NaN                NaN
# 5              55256              59531
# 6                NaN                NaN
# 7              12547              10903
# 8               6068               5340
# 9              (340)           (32,590)

# %% [markdown]
# Make the column names into the fiscal years.

# %%
df.columns = ['label', 'fy_2020', 'fy_2019', 'fy_2018']
df.head(10)
# Out:
#                                                label            fy_2020  \
# 0                                                NaN                NaN
# 1                                                NaN        Years ended
# 2                                                NaN  September 26,2020
# 3  Cash, cash equivalents and restricted cash, be...              50224
# 4                              Operating activities:                NaN
# 5                                         Net income              57411
# 6  Adjustments to reconcile net income to cash ge...                NaN
# 7                      Depreciation and amortization              11056
# 8                   Share-based compensation expense               6829
# 9                        Deferred income tax benefit              (215)
#
#              fy_2019            fy_2018
# 0                NaN                NaN
# 1        Years ended        Years ended
# 2  September 28,2019  September 29,2018
# 3              25913              20289
# 4                NaN                NaN
# 5              55256              59531
# 6                NaN                NaN
# 7              12547              10903
# 8               6068               5340
# 9              (340)           (32,590)

# %% [markdown]
# That makes the first 3 rows obselete...

# %%
df = df.drop([0, 1, 2], axis=0)
df.head(10)
# Out:
#                                                 label fy_2020 fy_2019  \
# 3   Cash, cash equivalents and restricted cash, be...   50224   25913
# 4                               Operating activities:     NaN     NaN
# 5                                          Net income   57411   55256
# 6   Adjustments to reconcile net income to cash ge...     NaN     NaN
# 7                       Depreciation and amortization   11056   12547
# 8                    Share-based compensation expense    6829    6068
# 9                         Deferred income tax benefit   (215)   (340)
# 10                                              Other    (97)   (652)
# 11       Changes in operating assets and liabilities:     NaN     NaN
# 12                           Accounts receivable, net    6917     245
#
#      fy_2018
# 3      20289
# 4        NaN
# 5      59531
# 6        NaN
# 7      10903
# 8       5340
# 9   (32,590)
# 10     (444)
# 11       NaN
# 12   (5,322)

# %% [markdown]
# Move the labels to be row indices.

# %%
df = df.set_index('label')
df.head(10)
# Out:
#                                                    fy_2020 fy_2019   fy_2018
# label
# Cash, cash equivalents and restricted cash, beg...   50224   25913     20289
# Operating activities:                                  NaN     NaN       NaN
# Net income                                           57411   55256     59531
# Adjustments to reconcile net income to cash gen...     NaN     NaN       NaN
# Depreciation and amortization                        11056   12547     10903
# Share-based compensation expense                      6829    6068      5340
# Deferred income tax benefit                          (215)   (340)  (32,590)
# Other                                                 (97)   (652)     (444)
# Changes in operating assets and liabilities:           NaN     NaN       NaN
# Accounts receivable, net                              6917     245   (5,322)

# %% [markdown]
# ### Extraction
# We have what we need now -- let's just look at the fields we're interested in.

# %%
# It can be helpful to look at the labels we'll have to pick from. Remember, they're
# stored in the (row) index now.
df.index
# Out:
# Index(['Cash, cash equivalents and restricted cash, beginning balances',
#        'Operating activities:', 'Net income',
#        'Adjustments to reconcile net income to cash generated by operating activities:',
#        'Depreciation and amortization', 'Share-based compensation expense',
#        'Deferred income tax benefit', 'Other',
#        'Changes in operating assets and liabilities:',
#        'Accounts receivable, net', 'Inventories',
#        'Vendor non-trade receivables', 'Other current and non-current assets',
#        'Accounts payable', 'Deferred revenue',
#        'Other current and non-current liabilities',
#        'Cash generated by operating activities', 'Investing activities:',
#        'Purchases of marketable securities',
#        'Proceeds from maturities of marketable securities',
#        'Proceeds from sales of marketable securities',
#        'Payments for acquisition of property, plant and equipment',
#        'Payments made in connection with business acquisitions, net',
#        'Purchases of non-marketable securities',
#        'Proceeds from non-marketable securities', 'Other',
#        'Cash generated by/(used in) investing activities',
#        'Financing activities:', 'Proceeds from issuance of common stock',
#        'Payments for taxes related to net share settlement of equity awards',
#        'Payments for dividends and dividend equivalents',
#        'Repurchases of common stock',
#        'Proceeds from issuance of term debt, net', 'Repayments of term debt',
#        'Repayments of commercial paper, net', 'Other',
#        'Cash used in financing activities',
#        'Increase/(Decrease) in cash, cash equivalents and restricted cash',
#        'Cash, cash equivalents and restricted cash, ending balances',
#        'Supplemental cash flow disclosure:', 'Cash paid for income taxes, net',
#        'Cash paid for interest'],
#       dtype='object', name='label')

# %% [markdown]
# We can copy and paste label names from above so we know we get it exactly right.

# %% [markdown]
# #### Operating Cash

# %%
# Change in cash from operating activities
operating_label = 'Cash generated by operating activities'
delta_operating = int(df.loc[operating_label, 'fy_2020']) - int(df.loc[operating_label, 'fy_2019'])
delta_operating
# Out:
# 11283

# %% [markdown]
# #### Investing Cash

# %%
# Change in cash from investing activities
investing_label = 'Cash generated by/(used in) investing activities'
delta_investing = int(df.loc[investing_label, 'fy_2020']) - int(df.loc[investing_label, 'fy_2019'])
delta_investing
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-f9358459a11e> in <module>
#       1 # Change in cash from investing activities
#       2 investing_label = 'Cash generated by/(used in) investing activities'
# ----> 3 delta_investing = int(df.loc[investing_label, 'fy_2020']) - int(df.loc[investing_label, 'fy_2019'])
#       4 delta_investing
#
# ValueError: invalid literal for int() with base 10: '(4,289)'

# %% [markdown]
# Uh oh! We ran into a number in parenthesis, which can't automatically be converted into an integer.
# Parentheses indicate negative numbers in financial statements, so we'll have to work more carefully with this one.

# %%
investing_2020 = df.loc[investing_label, 'fy_2020']
investing_2019 = df.loc[investing_label, 'fy_2019']
investing_2020, investing_2019
# Out:
# ('(4,289)', '45896')

# %% [markdown]
# So the first is negative.
# We could change this by hand (just compare `-4289` to `45896`), but a more elegant way would be to do it programmatically.

# %%
def normalize_number(number):
    '''
    Takes a number as a string and returns it as an integer. If the number has parens,
    it will be returned as a negative.
    '''
    # Turn parenthetical numbers into negatives
    if '(' in number:
        # Number is a string, so we can strip characters and add a negative sign at the front.
        number = number.strip('()')
        number = '-' + number
    return int(number)

# %% [markdown]
# Now we can call our function on **any** number we find in a financial statement, to safely convert it to a positive or negative integer.

# %%
normalize_number(investing_2020), normalize_number(investing_2019)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-40efb81fb5c8> in <module>
# ----> 1 normalize_number(investing_2020), normalize_number(investing_2019)
#
# <ipython-input-35-5fa7f20f4b54> in normalize_number(number)
#       9         number = number.strip('()')
#      10         number = '-' + number
# ---> 11     return int(number)
#
# ValueError: invalid literal for int() with base 10: '-4,289'

# %% [markdown]
# Oh! And now we have to deal with commas too, which Python doesn't like. Let's modify our function slightly.

# %%
def normalize_number(number):
    '''
    Takes a number as a string and returns it as an integer. If the number has parens,
    it will be returned as a negative.
    '''
    # Turn parenthetical numbers into negatives
    if '(' in number:
        # Number is a string, so we can strip characters and add a negative sign at the front.
        number = number.strip('()')
        number = '-' + number
    # Remove commas
    number = number.replace(',', '')
    return int(number)

# %%
normalize_number(investing_2020), normalize_number(investing_2019)
# Out:
# (-4289, 45896)

# %%
delta_investing = normalize_number(investing_2020) - normalize_number(investing_2019)
delta_investing
# Out:
# -50185

# %% [markdown]
# #### Financing Cash

# %%
# Change in cash from financing activities
financing_label = 'Cash used in financing activities'
delta_financing = int(df.loc[financing_label, 'fy_2020']) - int(df.loc[financing_label, 'fy_2019'])
delta_financing
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-bc86290324a1> in <module>
#       1 # Change in cash from financing activities
#       2 financing_label = 'Cash used in financing activities'
# ----> 3 delta_financing = int(df.loc[financing_label, 'fy_2020']) - int(df.loc[financing_label, 'fy_2019'])
#       4 delta_financing
#
# ValueError: invalid literal for int() with base 10: '(86,820)'

# %% [markdown]
# Looks like we need our function again! The great thing about functions is that you can reuse them.

# %%
delta_financing = normalize_number(df.loc[financing_label, 'fy_2020']) - normalize_number(df.loc[financing_label, 'fy_2019'])
delta_financing
# Out:
# 4156

# %% [markdown]
# #### Comparing Them

# %%
print('Change in operating cash:', delta_operating)
print('Change in investing cash:', delta_investing)
print('Change in financing cash:', delta_financing)
# Out:
# Change in operating cash: 11283
# Change in investing cash: -50185
# Change in financing cash: 4156

# %% [markdown]
# So the greatest change from 2019 to 2020 was in Apple's investment, which decreased by $50 billion. Interesting.
# We can even look at the amounts.

# %%
investing_2020, investing_2019
# Out:
# ('(4,289)', '45896')

# %% [markdown]
# So they went from *making* $46b on investments to *losing* 5 billion. Quite a swing.
